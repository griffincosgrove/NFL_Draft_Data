# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib as mtp
# %matplotlib inline

# %%
df = pd.read_csv('combine_data.csv')

# %%
df.describe()
# Out:
#                 Ht           Wt        Forty     Vertical    BenchReps  \
# count  6218.000000  6218.000000  6046.000000  4796.000000  4212.000000
# mean     73.798971   243.372145     4.783784    32.818599    20.926163
# std       2.621373    45.103814     0.305984     4.213729     6.393679
# min      65.000000   149.000000     4.220000    17.500000     2.000000
# 25%      72.000000   206.000000     4.540000    30.000000    16.000000
# 50%      74.000000   233.000000     4.700000    33.000000    21.000000
# 75%      76.000000   281.000000     4.980000    35.500000    25.000000
# max      82.000000   375.000000     6.050000    46.000000    49.000000
#
#          BroadJump         Cone      Shuttle         Year           AV  \
# count  4754.000000  3993.000000  4063.000000  6218.000000  6218.000000
# mean    113.943837     7.282307     4.390603  2009.041975     5.085719
# std       9.317031     0.422882     0.268836     5.471056     7.546556
# ...

# %%
df.head()
# Out:
#              Player  Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 0      John Abraham  OLB  76  252   4.55       NaN        NaN        NaN
# 1   Shaun Alexander   RB  72  218   4.58       NaN        NaN        NaN
# 2    Darnell Alford   OT  76  334   5.56      25.0       23.0       94.0
# 3      Kyle Allamon   TE  74  253   4.97      29.0        NaN      104.0
# 4  Rashard Anderson   CB  74  206   4.55      34.0        NaN      123.0
#
#    Cone  Shuttle  Year    Pfr_ID    AV                Team  Round   Pick
# 0   NaN      NaN  2000  AbraJo00  26.0       New York Jets    1.0   13.0
# 1   NaN      NaN  2000  AlexSh00  26.0    Seattle Seahawks    1.0   19.0
# 2  8.48     4.98  2000  AlfoDa20   0.0  Kansas City Chiefs    6.0  188.0
# 3  7.29     4.49  2000       NaN   0.0                 NaN    NaN    NaN
# 4  7.18     4.15  2000  AndeRa21   6.0   Carolina Panthers    1.0   23.0

# %%
qb_df = df[ df['Pos'] == 'QB']
qb_df.head()
# Out:
#                Player Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 27          Tom Brady  QB  76  211   5.28      24.5        NaN       99.0
# 29    Travis Brown-01  QB  75  218   5.01      29.0        NaN      101.0
# 36        Marc Bulger  QB  74  208   4.97       NaN        NaN      100.0
# 38         Bill Burke  QB  76  206   5.03      28.5        NaN      107.0
# 43  Giovanni Carmazzi  QB  75  224   4.74      36.5        NaN      119.0
#
#     Cone  Shuttle  Year    Pfr_ID    AV                  Team  Round   Pick
# 27  7.20     4.38  2000  BradTo00  25.0  New England Patriots    6.0  199.0
# 29  7.54     4.87  2000  BrowTr01   1.0                   NaN    NaN    NaN
# 36  7.46     4.34  2000  BulgMa00  31.0    New Orleans Saints    6.0  168.0
# 38  7.46     4.42  2000       NaN   0.0                   NaN    NaN    NaN
# 43  6.94     4.23  2000       NaN   0.0                   NaN    NaN    NaN

# %%
qb_df.describe()
# Out:
#                Ht          Wt       Forty    Vertical  BenchReps   BroadJump  \
# count  350.000000  350.000000  343.000000  289.000000  19.000000  293.000000
# mean    74.731429  222.800000    4.828542   31.076125  19.210526  110.136519
# std      1.700122   11.740265    0.175520    3.236524   4.130899    6.633905
# min     70.000000  192.000000    4.330000   21.500000  11.000000   91.000000
# 25%     74.000000  215.000000    4.710000   29.000000  16.000000  106.000000
# 50%     75.000000  223.000000    4.830000   31.000000  19.000000  110.000000
# 75%     76.000000  229.000000    4.930000   33.000000  22.000000  114.000000
# max     79.000000  288.000000    5.370000   40.000000  26.000000  128.000000
#
#              Cone     Shuttle         Year          AV       Round        Pick
# count  273.000000  277.000000   350.000000  350.000000  194.000000  194.000000
# mean     7.152564    4.323321  2008.842857    4.514286    3.742268  109.876289
# ...

# %%
qb_correlation_matrix = qb_df.corr().round(2)
sn.heatmap(data = qb_correlation_matrix, annot = True, linewidths = .5)

# %%
# nothing is jumping out at me on the QB heatmap.

# %%
rb_df = df[ df['Pos'] == 'RB']
rb_df.head()
# Out:
#              Player Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  Cone  \
# 1   Shaun Alexander  RB  72  218   4.58       NaN        NaN        NaN   NaN
# 32      Keith Brown  RB  71  216   4.66      30.0        NaN      117.0  6.64
# 33    Demario Brown  RB  72  217   4.72      31.0        NaN      107.0  7.17
# 41   Trung Canidate  RB  71  193   4.41       NaN       18.0        NaN   NaN
# 48     Doug Chapman  RB  70  215   4.56      38.5       16.0      128.0  6.84
#
#     Shuttle  Year    Pfr_ID    AV               Team  Round  Pick
# 1       NaN  2000  AlexSh00  26.0   Seattle Seahawks    1.0  19.0
# 32     4.08  2000       NaN   0.0                NaN    NaN   NaN
# 33     4.39  2000       NaN   0.0                NaN    NaN   NaN
# 41      NaN  2000  CaniTr00   6.0     St. Louis Rams    1.0  31.0
# 48     4.20  2000  ChapDo00   3.0  Minnesota Vikings    3.0  88.0

# %%
rb_correlation_matrix = rb_df.corr().round(2)
sn.heatmap(data = rb_correlation_matrix, annot = True, linewidths = .5)

# %%
# lets see if we can find anything only looking at round 1 picks.

rbg_df = df.groupby("Pos")
rbg_df.get_group("RB").head()

for row in rbg_df:
    if (rbg_df('Round') != '1.0'):
        rbg_df.drop()
# Out:
#              Player Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  Cone  \
# 1   Shaun Alexander  RB  72  218   4.58       NaN        NaN        NaN   NaN
# 32      Keith Brown  RB  71  216   4.66      30.0        NaN      117.0  6.64
# 33    Demario Brown  RB  72  217   4.72      31.0        NaN      107.0  7.17
# 41   Trung Canidate  RB  71  193   4.41       NaN       18.0        NaN   NaN
# 48     Doug Chapman  RB  70  215   4.56      38.5       16.0      128.0  6.84
#
#     Shuttle  Year    Pfr_ID    AV               Team  Round  Pick
# 1       NaN  2000  AlexSh00  26.0   Seattle Seahawks    1.0  19.0
# 32     4.08  2000       NaN   0.0                NaN    NaN   NaN
# 33     4.39  2000       NaN   0.0                NaN    NaN   NaN
# 41      NaN  2000  CaniTr00   6.0     St. Louis Rams    1.0  31.0
# 48     4.20  2000  ChapDo00   3.0  Minnesota Vikings    3.0  88.0
